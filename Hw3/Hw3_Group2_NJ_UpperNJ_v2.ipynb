# %% [markdown]
# <a href="https://colab.research.google.com/github/cglamb/Collab/blob/main/Hw3_Group2_NJ_LowerNJ.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Redistricting New Jersey

# %% [markdown]
# Group 2: Charles Lamb, Connor Cassedy, Heidi Huckabay, and Susan Alrifai

# %% [markdown]
# ### Library Import

# %%
pip install pulp
# Out:
# Requirement already satisfied: pulp in c:\users\cglam\anaconda3\lib\site-packages (2.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#import libraries
import pulp, numpy as np, pandas as pd, math
from pulp import *

# %% [markdown]
# ### New Jersey State Data

# %% [markdown]
# Data source is US Census data containing 2020 population size by county for the state of New Jersey: https://www.census.gov/data/tables/time-series/demo/popest/2020s-counties-total.html

# %%
#bringing in county and population as list
county_pop = [['Warren',109638],['Hunterdon',128962],['Sussex',144231],['Somerset',345356],['Mercer',387340],['Morris',509277],['Passaic',525052],['Union',575352],['Hudson',724857],['Essex',862782],['Middlesex',863183],['Bergen',955746]]

# %%
#setting up a dataframe
df0 = pd.DataFrame(county_pop,columns=['county','pop'])

# %%
#checking we have the appropriate number of counties in the dataframe
#per the assignment we expect to see 92
county_cnt = len(df0['county'].unique())
print(county_cnt)
# Out:
# 12

# %% [markdown]
# ### Adjacent Pair Setup

# %% [markdown]
# Based on data from the following: https://www2.census.gov/geo/docs/reference/county_adjacency.txt

# %% [markdown]
# Some pre-proceesing was performed.  Pairs were found only for the state of Indiana.  And some many adjustment to county name conventions was made to be consistent with the rest of data used in this file

# %%
county_pair_list= [['Bergen','Essex'],['Bergen','Hudson'],['Bergen','Passaic'],['Essex','Bergen'],['Essex','Hudson'],['Essex','Morris'],['Essex','Passaic'],['Essex','Union'],['Hudson','Bergen'],['Hudson','Essex'],['Hudson','Union'],['Hunterdon','Mercer'],['Hunterdon','Morris'],['Hunterdon','Somerset'],['Hunterdon','Warren'],['Mercer','Hunterdon'],['Mercer','Middlesex'],['Mercer','Somerset'],['Middlesex','Mercer'],['Middlesex','Somerset'],['Middlesex','Union'],['Morris','Essex'],['Morris','Hunterdon'],['Morris','Passaic'],['Morris','Somerset'],['Morris','Sussex'],['Morris','Union'],['Morris','Warren'],['Passaic','Bergen'],['Passaic','Essex'],['Passaic','Morris'],['Passaic','Sussex'],['Somerset','Hunterdon'],['Somerset','Mercer'],['Somerset','Middlesex'],['Somerset','Morris'],['Somerset','Union'],['Sussex','Morris'],['Sussex','Passaic'],['Sussex','Warren'],['Union','Essex'],['Union','Hudson'],['Union','Middlesex'],['Union','Morris'],['Union','Somerset'],['Warren','Hunterdon'],['Warren','Morris'],['Warren','Sussex']]

# %%
df_pair = pd.DataFrame(county_pair_list, columns=['county','adj_county'])

# %% [markdown]
# ### Total Pop Count

# %%
state_pop = df0['pop'].sum()

# %% [markdown]
# ### Global Variables

# %%
num_counties = county_cnt #number of counties
num_leg_districits = 8 #number of legistlative districts
pop_per_rep = 9289031 / 12 #gives us population per representative
pop_sen = 1.5 #variance we will allow in district pop from average
pop_max = pop_per_rep * pop_sen #max pop allowed in each legislative district
pop_min = pop_per_rep / pop_sen #min pop allowed in each legislative district

# %% [markdown]
# ### Looking for Counties with Populations within the Pop Range

# %%
df0[df0['pop'] >= pop_min]['county']
# Out:
# 6       Passaic
# 7         Union
# 8        Hudson
# 9         Essex
# 10    Middlesex
# 11       Bergen
# Name: county, dtype: object

# %%
isolate_list = df0[df0['pop'] >= pop_min]['county']

# %% [markdown]
# ### Setup

# %%
#creating a variable for each county.
counties = df0['county'].unique()

# %%
#creating a variable for each district
district = list(range(0,num_leg_districits))

# %%
#creating a population dictionary
pop_list = df0['pop']
pop = dict(zip(counties, pop_list))

# %%
#adjacency dictionary
adj_dict = df_pair.groupby('county')['adj_county'].apply(list).to_dict()

# %% [markdown]
# ### Creating All Possible Adjacent Pairs

# %%
pair_temp = []
sorted_pair_temp = []
start_county = []
end_county = []
for i in counties:
    for p in adj_dict[i]:
       pair_temp.append(i+p)
       sorted_pair_temp.append(sorted(i+p))
       start_county.append(i)
       end_county.append(p)
d = {'pair_list':pair_temp,'sorted':sorted_pair_temp,"start":start_county,"end":end_county}
df = pd.DataFrame(d)
key_list = df.sorted.drop_duplicates().keys()
pair_list = df.pair_list[key_list]
start_list = df.start[key_list]
end_list = df.end[key_list]

# %% [markdown]
# ### Creating a dataframe of each pair within each district layer

# %%
#this will help built the constraint a little quicker, so doing this here and now
pair_list2  = [(p,d) for p in pair_list for d in district]
start_list2  = [(s,d) for s in start_list for d in district]
end_list2  = [(e,d) for e in end_list for d in district]
d2 = {'pair_list':pair_list2,'start':start_list2,"end":end_list2}
df2 = pd.DataFrame(d2)

# %% [markdown]
# ### Establishing Variables

# %%
#establish county/district variables
county_district = LpVariable.dicts("xij",[(c,d) for c in counties for d in district],0,1,cat="Integer")
adj_pair = LpVariable.dicts("xprime",[p for p in pair_list],0,1,cat="Integer")

# %% [markdown]
# ### Objective Function

# %%
#setting up problem
prob = LpProblem("problem",LpMinimize)
prob += lpSum([adj_pair[i] for i in adj_pair])

# %% [markdown]
# ### Establishing constraints

# %%
#making sure each county is assigned to one and only one district
for c in counties:
    prob += lpSum([county_district[(c,d)] for d in district]) == 1

#making sure each county is assigned to one and only one district
    #prob += lpSum([county_district[(c,0)]*pre_asign_dict[c] for c in counties]) == 1

#setting up constraints on max population in each district
for d in district:
    prob += lpSum([county_district[(i,d)] * pop[i] for i in counties]) <= pop_max
    
#setting up constraints on min population in each district
for d in district:
    prob += lpSum([county_district[(i,d)] * pop[i] for i in counties]) >= pop_min

#cut edge variables
for i in range(len(pair_list2)):
    prob += adj_pair[list(adj_pair)[math.ceil(i/num_leg_districits)-1]] >= county_district[start_list2[i]] - county_district[end_list2[i]]

for i in range(len(pair_list2)):
    prob += adj_pair[list(adj_pair)[math.ceil(i/num_leg_districits)-1]] >= county_district[end_list2[i]] - county_district[start_list2[i]]
    
#mandating adjacency:
for d in district:
    #prob += county_district["Atlantic",d] <= county_district["Burlington",d] + county_district["Camden",d] + county_district["Cape",d]  + county_district["Cumberland",d] + county_district["Gloucester",d] + county_district["Ocean",d]
    #prob += county_district["Burlington",d] <= county_district["Atlantic",d] + county_district["Camden",d] + county_district["Mercer",d]  + county_district["Monmouth",d] + county_district["Ocean",d] 
    #prob += county_district["Camden",d] <= county_district["Burlington",d] + county_district["Atlantic",d] + county_district["Gloucester",d]
    #prob += county_district["Cape",d] <= county_district["Cumberland",d] + county_district["Atlantic",d]
    #prob += county_district["Cumberland",d] <= county_district["Salem",d] + county_district["Gloucester",d] + county_district["Atlantic",d] + county_district["Cape",d] 
    #prob += county_district["Gloucester",d] <= county_district["Salem",d] + county_district["Cumberland",d] + county_district["Atlantic",d] + county_district["Camden",d]
    prob += county_district["Hunterdon",d] <= county_district["Mercer",d] + county_district["Morris",d] + county_district["Somerset",d] + county_district["Warren",d] 
    prob += county_district["Mercer",d] <= + county_district["Hunterdon",d] + county_district["Middlesex",d] + county_district["Somerset",d] 
    #prob += county_district["Monmouth",d] <= county_district["Burlington",d] + county_district["Mercer",d] + county_district["Middlesex",d] + county_district["Ocean",d] 
    prob += county_district["Morris",d] <= county_district["Essex",d] + county_district["Hunterdon",d] + county_district["Passaic",d] + county_district["Somerset",d] + county_district["Sussex",d] + county_district["Union",d] + county_district["Warren",d] 
    #prob += county_district["Ocean",d] <= county_district["Atlantic",d] + county_district["Burlington",d] + county_district["Monmouth",d]
    prob += county_district["Passaic",d] <= county_district["Bergen",d] + county_district["Essex",d] + county_district["Morris",d] + county_district["Sussex",d]
    #prob += county_district["Salem",d] <= county_district["Gloucester",d] + county_district["Cumberland",d]  
    prob += county_district["Somerset",d] <= county_district["Hunterdon",d] + county_district["Mercer",d] + county_district["Middlesex",d] + county_district["Morris",d] + county_district["Union",d]
    prob += county_district["Sussex",d] <= county_district["Morris",d] + county_district["Passaic",d] + county_district["Warren",d]                 
    prob += county_district["Union",d] <= county_district["Essex",d] + county_district["Hudson",d] + county_district["Middlesex",d] + county_district["Morris",d] + county_district["Somerset",d]

# %% [markdown]
# ### Solve

# %%
prob.solve()
# Out:
# 1

# %% [markdown]
# ### Show the Assignment of County to Legislative District

# %%
assignment_list = []
assignment_county = []
assignment_district = []
assignment_pop = []
for i in county_district:
    assignment_list.append(county_district[i].varValue)
for c in counties:
    for j in district:
        assignment_county.append(c)
        assignment_district.append(j)
        assignment_pop.append(pop[c])
d3 = {"County":assignment_county, "Legislative_District": assignment_district, "assignment_list": assignment_list, "pop": assignment_pop}
df3 = pd.DataFrame(d3)
df3 = df3[df3['assignment_list'] == 1]

# %%
df3.groupby('Legislative_District')['County'].apply(' '.join).reset_index()
# Out:
#    Legislative_District            County
# 0                     0            Bergen
# 1                     1     Warren Morris
# 2                     2  Hunterdon Mercer
# 3                     3            Hudson
# 4                     4             Essex
# 5                     5         Middlesex
# 6                     6    Somerset Union
# 7                     7    Sussex Passaic

# %%
df3.groupby('Legislative_District')['pop'].sum().reset_index()
# Out:
#    Legislative_District     pop
# 0                     0  955746
# 1                     1  618915
# 2                     2  516302
# 3                     3  724857
# 4                     4  862782
# 5                     5  863183
# 6                     6  920708
# 7                     7  669283

# %%
df3.to_excel('output_LowerNJ.xlsx')

# %% [markdown]
# ### Check

# %%
for variable in prob.variables():
    print(f'{variable}: {value(variable.varValue)}')
# Out:
# xij_('Bergen',_0): 1.0
# xij_('Bergen',_1): 0.0
# xij_('Bergen',_2): 0.0
# xij_('Bergen',_3): 0.0
# xij_('Bergen',_4): 0.0
# xij_('Bergen',_5): 0.0
# xij_('Bergen',_6): 0.0
# xij_('Bergen',_7): 0.0
# xij_('Essex',_0): 0.0
# xij_('Essex',_1): 0.0
# xij_('Essex',_2): 0.0
# xij_('Essex',_3): 0.0
# xij_('Essex',_4): 1.0
# xij_('Essex',_5): 0.0
# xij_('Essex',_6): 0.0
# xij_('Essex',_7): 0.0
# xij_('Hudson',_0): 0.0
# xij_('Hudson',_1): 0.0
# xij_('Hudson',_2): 0.0
# xij_('Hudson',_3): 1.0
# xij_('Hudson',_4): 0.0
# xij_('Hudson',_5): 0.0
# xij_('Hudson',_6): 0.0
# xij_('Hudson',_7): 0.0
# xij_('Hunterdon',_0): 0.0
# xij_('Hunterdon',_1): 0.0
# xij_('Hunterdon',_2): 1.0
# xij_('Hunterdon',_3): 0.0
# xij_('Hunterdon',_4): 0.0
# xij_('Hunterdon',_5): 0.0
# xij_('Hunterdon',_6): 0.0
# xij_('Hunterdon',_7): 0.0
# xij_('Mercer',_0): 0.0
# xij_('Mercer',_1): 0.0
# xij_('Mercer',_2): 1.0
# xij_('Mercer',_3): 0.0
# xij_('Mercer',_4): 0.0
# xij_('Mercer',_5): 0.0
# xij_('Mercer',_6): 0.0
# xij_('Mercer',_7): 0.0
# xij_('Middlesex',_0): 0.0
# xij_('Middlesex',_1): 0.0
# xij_('Middlesex',_2): 0.0
# xij_('Middlesex',_3): 0.0
# xij_('Middlesex',_4): 0.0
# xij_('Middlesex',_5): 1.0
# xij_('Middlesex',_6): 0.0
# xij_('Middlesex',_7): 0.0
# xij_('Morris',_0): 0.0
# xij_('Morris',_1): 1.0
# xij_('Morris',_2): 0.0
# xij_('Morris',_3): 0.0
# xij_('Morris',_4): 0.0
# xij_('Morris',_5): 0.0
# xij_('Morris',_6): 0.0
# xij_('Morris',_7): 0.0
# xij_('Passaic',_0): 0.0
# xij_('Passaic',_1): 0.0
# xij_('Passaic',_2): 0.0
# xij_('Passaic',_3): 0.0
# xij_('Passaic',_4): 0.0
# xij_('Passaic',_5): 0.0
# xij_('Passaic',_6): 0.0
# xij_('Passaic',_7): 1.0
# xij_('Somerset',_0): 0.0
# xij_('Somerset',_1): 0.0
# xij_('Somerset',_2): 0.0
# xij_('Somerset',_3): 0.0
# xij_('Somerset',_4): 0.0
# xij_('Somerset',_5): 0.0
# xij_('Somerset',_6): 1.0
# xij_('Somerset',_7): 0.0
# xij_('Sussex',_0): 0.0
# xij_('Sussex',_1): 0.0
# xij_('Sussex',_2): 0.0
# xij_('Sussex',_3): 0.0
# xij_('Sussex',_4): 0.0
# xij_('Sussex',_5): 0.0
# xij_('Sussex',_6): 0.0
# xij_('Sussex',_7): 1.0
# xij_('Union',_0): 0.0
# xij_('Union',_1): 0.0
# xij_('Union',_2): 0.0
# xij_('Union',_3): 0.0
# xij_('Union',_4): 0.0
# xij_('Union',_5): 0.0
# xij_('Union',_6): 1.0
# xij_('Union',_7): 0.0
# xij_('Warren',_0): 0.0
# xij_('Warren',_1): 1.0
# xij_('Warren',_2): 0.0
# xij_('Warren',_3): 0.0
# xij_('Warren',_4): 0.0
# xij_('Warren',_5): 0.0
# xij_('Warren',_6): 0.0
# xij_('Warren',_7): 0.0
# xprime_EssexBergen: 1.0
# xprime_HudsonBergen: 1.0
# xprime_HudsonEssex: 1.0
# xprime_HunterdonMercer: 0.0
# xprime_HunterdonMorris: 1.0
# xprime_HunterdonSomerset: 1.0
# xprime_MercerMiddlesex: 1.0
# xprime_MorrisEssex: 1.0
# xprime_MorrisPassaic: 1.0
# xprime_MorrisUnion: 1.0
# xprime_PassaicBergen: 1.0
# xprime_PassaicEssex: 1.0
# xprime_SomersetMercer: 1.0
# xprime_SomersetMiddlesex: 1.0
# xprime_SomersetMorris: 1.0
# xprime_SomersetUnion: 0.0
# xprime_SussexMorris: 1.0
# xprime_SussexPassaic: 0.0
# xprime_UnionEssex: 1.0
# xprime_UnionHudson: 1.0
# xprime_UnionMiddlesex: 1.0
# xprime_WarrenHunterdon: 1.0
# xprime_WarrenMorris: 0.0
# xprime_WarrenSussex: 1.0

# %%
print(prob)
# Out:
# problem:
# MINIMIZE
# 1*xprime_EssexBergen + 1*xprime_HudsonBergen + 1*xprime_HudsonEssex + 1*xprime_HunterdonMercer + 1*xprime_HunterdonMorris + 1*xprime_HunterdonSomerset + 1*xprime_MercerMiddlesex + 1*xprime_MorrisEssex + 1*xprime_MorrisPassaic + 1*xprime_MorrisUnion + 1*xprime_PassaicBergen + 1*xprime_PassaicEssex + 1*xprime_SomersetMercer + 1*xprime_SomersetMiddlesex + 1*xprime_SomersetMorris + 1*xprime_SomersetUnion + 1*xprime_SussexMorris + 1*xprime_SussexPassaic + 1*xprime_UnionEssex + 1*xprime_UnionHudson + 1*xprime_UnionMiddlesex + 1*xprime_WarrenHunterdon + 1*xprime_WarrenMorris + 1*xprime_WarrenSussex + 0
# SUBJECT TO
# _C1: xij_('Warren',_0) + xij_('Warren',_1) + xij_('Warren',_2)
#  + xij_('Warren',_3) + xij_('Warren',_4) + xij_('Warren',_5)
#  + xij_('Warren',_6) + xij_('Warren',_7) = 1
#
# _C2: xij_('Hunterdon',_0) + xij_('Hunterdon',_1) + xij_('Hunterdon',_2)
#  + xij_('Hunterdon',_3) + xij_('Hunterdon',_4) + xij_('Hunterdon',_5)
#  + xij_('Hunterdon',_6) + xij_('Hunterdon',_7) = 1
#
# _C3: xij_('Sussex',_0) + xij_('Sussex',_1) + xij_('Sussex',_2)
#  + xij_('Sussex',_3) + xij_('Sussex',_4) + xij_('Sussex',_5)
#  + xij_('Sussex',_6) + xij_('Sussex',_7) = 1
#
# _C4: xij_('Somerset',_0) + xij_('Somerset',_1) + xij_('Somerset',_2)
#  + xij_('Somerset',_3) + xij_('Somerset',_4) + xij_('Somerset',_5)
#  + xij_('Somerset',_6) + xij_('Somerset',_7) = 1
#
# _C5: xij_('Mercer',_0) + xij_('Mercer',_1) + xij_('Mercer',_2)
#  + xij_('Mercer',_3) + xij_('Mercer',_4) + xij_('Mercer',_5)
#  + xij_('Mercer',_6) + xij_('Mercer',_7) = 1
#
# _C6: xij_('Morris',_0) + xij_('Morris',_1) + xij_('Morris',_2)
#  + xij_('Morris',_3) + xij_('Morris',_4) + xij_('Morris',_5)
#  + xij_('Morris',_6) + xij_('Morris',_7) = 1
#
# _C7: xij_('Passaic',_0) + xij_('Passaic',_1) + xij_('Passaic',_2)
#  + xij_('Passaic',_3) + xij_('Passaic',_4) + xij_('Passaic',_5)
#  + xij_('Passaic',_6) + xij_('Passaic',_7) = 1
#
# _C8: xij_('Union',_0) + xij_('Union',_1) + xij_('Union',_2) + xij_('Union',_3)
#  + xij_('Union',_4) + xij_('Union',_5) + xij_('Union',_6) + xij_('Union',_7)
#  = 1
#
# _C9: xij_('Hudson',_0) + xij_('Hudson',_1) + xij_('Hudson',_2)
#  + xij_('Hudson',_3) + xij_('Hudson',_4) + xij_('Hudson',_5)
#  + xij_('Hudson',_6) + xij_('Hudson',_7) = 1
#
# _C10: xij_('Essex',_0) + xij_('Essex',_1) + xij_('Essex',_2)
#  + xij_('Essex',_3) + xij_('Essex',_4) + xij_('Essex',_5) + xij_('Essex',_6)
#  + xij_('Essex',_7) = 1
#
# _C11: xij_('Middlesex',_0) + xij_('Middlesex',_1) + xij_('Middlesex',_2)
#  + xij_('Middlesex',_3) + xij_('Middlesex',_4) + xij_('Middlesex',_5)
#  + xij_('Middlesex',_6) + xij_('Middlesex',_7) = 1
#
# _C12: xij_('Bergen',_0) + xij_('Bergen',_1) + xij_('Bergen',_2)
#  + xij_('Bergen',_3) + xij_('Bergen',_4) + xij_('Bergen',_5)
#  + xij_('Bergen',_6) + xij_('Bergen',_7) = 1
#
# _C13: 955746 xij_('Bergen',_0) + 862782 xij_('Essex',_0)
#  + 724857 xij_('Hudson',_0) + 128962 xij_('Hunterdon',_0)
#  + 387340 xij_('Mercer',_0) + 863183 xij_('Middlesex',_0)
#  + 509277 xij_('Morris',_0) + 525052 xij_('Passaic',_0)
#  + 345356 xij_('Somerset',_0) + 144231 xij_('Sussex',_0)
#  + 575352 xij_('Union',_0) + 109638 xij_('Warren',_0) <= 1161128.875
#
# _C14: 955746 xij_('Bergen',_1) + 862782 xij_('Essex',_1)
#  + 724857 xij_('Hudson',_1) + 128962 xij_('Hunterdon',_1)
#  + 387340 xij_('Mercer',_1) + 863183 xij_('Middlesex',_1)
#  + 509277 xij_('Morris',_1) + 525052 xij_('Passaic',_1)
#  + 345356 xij_('Somerset',_1) + 144231 xij_('Sussex',_1)
#  + 575352 xij_('Union',_1) + 109638 xij_('Warren',_1) <= 1161128.875
#
# _C15: 955746 xij_('Bergen',_2) + 862782 xij_('Essex',_2)
#  + 724857 xij_('Hudson',_2) + 128962 xij_('Hunterdon',_2)
#  + 387340 xij_('Mercer',_2) + 863183 xij_('Middlesex',_2)
#  + 509277 xij_('Morris',_2) + 525052 xij_('Passaic',_2)
#  + 345356 xij_('Somerset',_2) + 144231 xij_('Sussex',_2)
#  + 575352 xij_('Union',_2) + 109638 xij_('Warren',_2) <= 1161128.875
#
# _C16: 955746 xij_('Bergen',_3) + 862782 xij_('Essex',_3)
#  + 724857 xij_('Hudson',_3) + 128962 xij_('Hunterdon',_3)
#  + 387340 xij_('Mercer',_3) + 863183 xij_('Middlesex',_3)
#  + 509277 xij_('Morris',_3) + 525052 xij_('Passaic',_3)
#  + 345356 xij_('Somerset',_3) + 144231 xij_('Sussex',_3)
#  + 575352 xij_('Union',_3) + 109638 xij_('Warren',_3) <= 1161128.875
#
# _C17: 955746 xij_('Bergen',_4) + 862782 xij_('Essex',_4)
#  + 724857 xij_('Hudson',_4) + 128962 xij_('Hunterdon',_4)
#  + 387340 xij_('Mercer',_4) + 863183 xij_('Middlesex',_4)
#  + 509277 xij_('Morris',_4) + 525052 xij_('Passaic',_4)
#  + 345356 xij_('Somerset',_4) + 144231 xij_('Sussex',_4)
#  + 575352 xij_('Union',_4) + 109638 xij_('Warren',_4) <= 1161128.875
#
# _C18: 955746 xij_('Bergen',_5) + 862782 xij_('Essex',_5)
#  + 724857 xij_('Hudson',_5) + 128962 xij_('Hunterdon',_5)
#  + 387340 xij_('Mercer',_5) + 863183 xij_('Middlesex',_5)
#  + 509277 xij_('Morris',_5) + 525052 xij_('Passaic',_5)
#  + 345356 xij_('Somerset',_5) + 144231 xij_('Sussex',_5)
#  + 575352 xij_('Union',_5) + 109638 xij_('Warren',_5) <= 1161128.875
#
# _C19: 955746 xij_('Bergen',_6) + 862782 xij_('Essex',_6)
#  + 724857 xij_('Hudson',_6) + 128962 xij_('Hunterdon',_6)
#  + 387340 xij_('Mercer',_6) + 863183 xij_('Middlesex',_6)
#  + 509277 xij_('Morris',_6) + 525052 xij_('Passaic',_6)
#  + 345356 xij_('Somerset',_6) + 144231 xij_('Sussex',_6)
#  + 575352 xij_('Union',_6) + 109638 xij_('Warren',_6) <= 1161128.875
#
# _C20: 955746 xij_('Bergen',_7) + 862782 xij_('Essex',_7)
#  + 724857 xij_('Hudson',_7) + 128962 xij_('Hunterdon',_7)
#  + 387340 xij_('Mercer',_7) + 863183 xij_('Middlesex',_7)
#  + 509277 xij_('Morris',_7) + 525052 xij_('Passaic',_7)
#  + 345356 xij_('Somerset',_7) + 144231 xij_('Sussex',_7)
#  + 575352 xij_('Union',_7) + 109638 xij_('Warren',_7) <= 1161128.875
#
# _C21: 955746 xij_('Bergen',_0) + 862782 xij_('Essex',_0)
#  + 724857 xij_('Hudson',_0) + 128962 xij_('Hunterdon',_0)
#  + 387340 xij_('Mercer',_0) + 863183 xij_('Middlesex',_0)
#  + 509277 xij_('Morris',_0) + 525052 xij_('Passaic',_0)
#  + 345356 xij_('Somerset',_0) + 144231 xij_('Sussex',_0)
#  + 575352 xij_('Union',_0) + 109638 xij_('Warren',_0) >= 516057.277778
#
# _C22: 955746 xij_('Bergen',_1) + 862782 xij_('Essex',_1)
#  + 724857 xij_('Hudson',_1) + 128962 xij_('Hunterdon',_1)
#  + 387340 xij_('Mercer',_1) + 863183 xij_('Middlesex',_1)
#  + 509277 xij_('Morris',_1) + 525052 xij_('Passaic',_1)
#  + 345356 xij_('Somerset',_1) + 144231 xij_('Sussex',_1)
#  + 575352 xij_('Union',_1) + 109638 xij_('Warren',_1) >= 516057.277778
#
# _C23: 955746 xij_('Bergen',_2) + 862782 xij_('Essex',_2)
#  + 724857 xij_('Hudson',_2) + 128962 xij_('Hunterdon',_2)
#  + 387340 xij_('Mercer',_2) + 863183 xij_('Middlesex',_2)
#  + 509277 xij_('Morris',_2) + 525052 xij_('Passaic',_2)
#  + 345356 xij_('Somerset',_2) + 144231 xij_('Sussex',_2)
#  + 575352 xij_('Union',_2) + 109638 xij_('Warren',_2) >= 516057.277778
#
# _C24: 955746 xij_('Bergen',_3) + 862782 xij_('Essex',_3)
#  + 724857 xij_('Hudson',_3) + 128962 xij_('Hunterdon',_3)
#  + 387340 xij_('Mercer',_3) + 863183 xij_('Middlesex',_3)
#  + 509277 xij_('Morris',_3) + 525052 xij_('Passaic',_3)
#  + 345356 xij_('Somerset',_3) + 144231 xij_('Sussex',_3)
#  + 575352 xij_('Union',_3) + 109638 xij_('Warren',_3) >= 516057.277778
#
# _C25: 955746 xij_('Bergen',_4) + 862782 xij_('Essex',_4)
#  + 724857 xij_('Hudson',_4) + 128962 xij_('Hunterdon',_4)
#  + 387340 xij_('Mercer',_4) + 863183 xij_('Middlesex',_4)
#  + 509277 xij_('Morris',_4) + 525052 xij_('Passaic',_4)
#  + 345356 xij_('Somerset',_4) + 144231 xij_('Sussex',_4)
#  + 575352 xij_('Union',_4) + 109638 xij_('Warren',_4) >= 516057.277778
#
# _C26: 955746 xij_('Bergen',_5) + 862782 xij_('Essex',_5)
#  + 724857 xij_('Hudson',_5) + 128962 xij_('Hunterdon',_5)
#  + 387340 xij_('Mercer',_5) + 863183 xij_('Middlesex',_5)
#  + 509277 xij_('Morris',_5) + 525052 xij_('Passaic',_5)
#  + 345356 xij_('Somerset',_5) + 144231 xij_('Sussex',_5)
#  + 575352 xij_('Union',_5) + 109638 xij_('Warren',_5) >= 516057.277778
#
# _C27: 955746 xij_('Bergen',_6) + 862782 xij_('Essex',_6)
#  + 724857 xij_('Hudson',_6) + 128962 xij_('Hunterdon',_6)
#  + 387340 xij_('Mercer',_6) + 863183 xij_('Middlesex',_6)
#  + 509277 xij_('Morris',_6) + 525052 xij_('Passaic',_6)
#  + 345356 xij_('Somerset',_6) + 144231 xij_('Sussex',_6)
#  + 575352 xij_('Union',_6) + 109638 xij_('Warren',_6) >= 516057.277778
#
# _C28: 955746 xij_('Bergen',_7) + 862782 xij_('Essex',_7)
#  + 724857 xij_('Hudson',_7) + 128962 xij_('Hunterdon',_7)
#  + 387340 xij_('Mercer',_7) + 863183 xij_('Middlesex',_7)
#  + 509277 xij_('Morris',_7) + 525052 xij_('Passaic',_7)
#  + 345356 xij_('Somerset',_7) + 144231 xij_('Sussex',_7)
#  + 575352 xij_('Union',_7) + 109638 xij_('Warren',_7) >= 516057.277778
#
# _C29: xij_('Hunterdon',_0) - xij_('Warren',_0) + xprime_EssexBergen >= 0
#
# _C30: xij_('Hunterdon',_1) - xij_('Warren',_1) + xprime_WarrenHunterdon >= 0
#
# _C31: xij_('Hunterdon',_2) - xij_('Warren',_2) + xprime_WarrenHunterdon >= 0
#
# _C32: xij_('Hunterdon',_3) - xij_('Warren',_3) + xprime_WarrenHunterdon >= 0
#
# _C33: xij_('Hunterdon',_4) - xij_('Warren',_4) + xprime_WarrenHunterdon >= 0
#
# _C34: xij_('Hunterdon',_5) - xij_('Warren',_5) + xprime_WarrenHunterdon >= 0
#
# _C35: xij_('Hunterdon',_6) - xij_('Warren',_6) + xprime_WarrenHunterdon >= 0
#
# _C36: xij_('Hunterdon',_7) - xij_('Warren',_7) + xprime_WarrenHunterdon >= 0
#
# _C37: xij_('Morris',_0) - xij_('Warren',_0) + xprime_WarrenHunterdon >= 0
#
# _C38: xij_('Morris',_1) - xij_('Warren',_1) + xprime_WarrenMorris >= 0
#
# _C39: xij_('Morris',_2) - xij_('Warren',_2) + xprime_WarrenMorris >= 0
#
# _C40: xij_('Morris',_3) - xij_('Warren',_3) + xprime_WarrenMorris >= 0
#
# _C41: xij_('Morris',_4) - xij_('Warren',_4) + xprime_WarrenMorris >= 0
#
# _C42: xij_('Morris',_5) - xij_('Warren',_5) + xprime_WarrenMorris >= 0
#
# _C43: xij_('Morris',_6) - xij_('Warren',_6) + xprime_WarrenMorris >= 0
#
# _C44: xij_('Morris',_7) - xij_('Warren',_7) + xprime_WarrenMorris >= 0
#
# _C45: xij_('Sussex',_0) - xij_('Warren',_0) + xprime_WarrenMorris >= 0
#
# _C46: xij_('Sussex',_1) - xij_('Warren',_1) + xprime_WarrenSussex >= 0
#
# _C47: xij_('Sussex',_2) - xij_('Warren',_2) + xprime_WarrenSussex >= 0
#
# _C48: xij_('Sussex',_3) - xij_('Warren',_3) + xprime_WarrenSussex >= 0
#
# _C49: xij_('Sussex',_4) - xij_('Warren',_4) + xprime_WarrenSussex >= 0
#
# _C50: xij_('Sussex',_5) - xij_('Warren',_5) + xprime_WarrenSussex >= 0
#
# _C51: xij_('Sussex',_6) - xij_('Warren',_6) + xprime_WarrenSussex >= 0
#
# _C52: xij_('Sussex',_7) - xij_('Warren',_7) + xprime_WarrenSussex >= 0
#
# _C53: - xij_('Hunterdon',_0) + xij_('Mercer',_0) + xprime_WarrenSussex >= 0
#
# _C54: - xij_('Hunterdon',_1) + xij_('Mercer',_1) + xprime_HunterdonMercer >= 0
#
# _C55: - xij_('Hunterdon',_2) + xij_('Mercer',_2) + xprime_HunterdonMercer >= 0
#
# _C56: - xij_('Hunterdon',_3) + xij_('Mercer',_3) + xprime_HunterdonMercer >= 0
#
# _C57: - xij_('Hunterdon',_4) + xij_('Mercer',_4) + xprime_HunterdonMercer >= 0
#
# _C58: - xij_('Hunterdon',_5) + xij_('Mercer',_5) + xprime_HunterdonMercer >= 0
#
# _C59: - xij_('Hunterdon',_6) + xij_('Mercer',_6) + xprime_HunterdonMercer >= 0
#
# _C60: - xij_('Hunterdon',_7) + xij_('Mercer',_7) + xprime_HunterdonMercer >= 0
#
# _C61: - xij_('Hunterdon',_0) + xij_('Morris',_0) + xprime_HunterdonMercer >= 0
#
# _C62: - xij_('Hunterdon',_1) + xij_('Morris',_1) + xprime_HunterdonMorris >= 0
#
# _C63: - xij_('Hunterdon',_2) + xij_('Morris',_2) + xprime_HunterdonMorris >= 0
#
# _C64: - xij_('Hunterdon',_3) + xij_('Morris',_3) + xprime_HunterdonMorris >= 0
#
# _C65: - xij_('Hunterdon',_4) + xij_('Morris',_4) + xprime_HunterdonMorris >= 0
#
# _C66: - xij_('Hunterdon',_5) + xij_('Morris',_5) + xprime_HunterdonMorris >= 0
#
# _C67: - xij_('Hunterdon',_6) + xij_('Morris',_6) + xprime_HunterdonMorris >= 0
#
# _C68: - xij_('Hunterdon',_7) + xij_('Morris',_7) + xprime_HunterdonMorris >= 0
#
# _C69: - xij_('Hunterdon',_0) + xij_('Somerset',_0) + xprime_HunterdonMorris
#  >= 0
#
# _C70: - xij_('Hunterdon',_1) + xij_('Somerset',_1) + xprime_HunterdonSomerset
#  >= 0
#
# _C71: - xij_('Hunterdon',_2) + xij_('Somerset',_2) + xprime_HunterdonSomerset
#  >= 0
#
# _C72: - xij_('Hunterdon',_3) + xij_('Somerset',_3) + xprime_HunterdonSomerset
#  >= 0
#
# _C73: - xij_('Hunterdon',_4) + xij_('Somerset',_4) + xprime_HunterdonSomerset
#  >= 0
#
# _C74: - xij_('Hunterdon',_5) + xij_('Somerset',_5) + xprime_HunterdonSomerset
#  >= 0
#
# _C75: - xij_('Hunterdon',_6) + xij_('Somerset',_6) + xprime_HunterdonSomerset
#  >= 0
#
# _C76: - xij_('Hunterdon',_7) + xij_('Somerset',_7) + xprime_HunterdonSomerset
#  >= 0
#
# _C77: xij_('Morris',_0) - xij_('Sussex',_0) + xprime_HunterdonSomerset >= 0
#
# _C78: xij_('Morris',_1) - xij_('Sussex',_1) + xprime_SussexMorris >= 0
#
# _C79: xij_('Morris',_2) - xij_('Sussex',_2) + xprime_SussexMorris >= 0
#
# _C80: xij_('Morris',_3) - xij_('Sussex',_3) + xprime_SussexMorris >= 0
#
# _C81: xij_('Morris',_4) - xij_('Sussex',_4) + xprime_SussexMorris >= 0
#
# _C82: xij_('Morris',_5) - xij_('Sussex',_5) + xprime_SussexMorris >= 0
#
# _C83: xij_('Morris',_6) - xij_('Sussex',_6) + xprime_SussexMorris >= 0
#
# _C84: xij_('Morris',_7) - xij_('Sussex',_7) + xprime_SussexMorris >= 0
#
# _C85: xij_('Passaic',_0) - xij_('Sussex',_0) + xprime_SussexMorris >= 0
#
# _C86: xij_('Passaic',_1) - xij_('Sussex',_1) + xprime_SussexPassaic >= 0
#
# _C87: xij_('Passaic',_2) - xij_('Sussex',_2) + xprime_SussexPassaic >= 0
#
# _C88: xij_('Passaic',_3) - xij_('Sussex',_3) + xprime_SussexPassaic >= 0
#
# _C89: xij_('Passaic',_4) - xij_('Sussex',_4) + xprime_SussexPassaic >= 0
#
# _C90: xij_('Passaic',_5) - xij_('Sussex',_5) + xprime_SussexPassaic >= 0
#
# _C91: xij_('Passaic',_6) - xij_('Sussex',_6) + xprime_SussexPassaic >= 0
#
# _C92: xij_('Passaic',_7) - xij_('Sussex',_7) + xprime_SussexPassaic >= 0
#
# _C93: xij_('Mercer',_0) - xij_('Somerset',_0) + xprime_SussexPassaic >= 0
#
# _C94: xij_('Mercer',_1) - xij_('Somerset',_1) + xprime_SomersetMercer >= 0
#
# _C95: xij_('Mercer',_2) - xij_('Somerset',_2) + xprime_SomersetMercer >= 0
#
# _C96: xij_('Mercer',_3) - xij_('Somerset',_3) + xprime_SomersetMercer >= 0
#
# _C97: xij_('Mercer',_4) - xij_('Somerset',_4) + xprime_SomersetMercer >= 0
#
# _C98: xij_('Mercer',_5) - xij_('Somerset',_5) + xprime_SomersetMercer >= 0
#
# _C99: xij_('Mercer',_6) - xij_('Somerset',_6) + xprime_SomersetMercer >= 0
#
# _C100: xij_('Mercer',_7) - xij_('Somerset',_7) + xprime_SomersetMercer >= 0
#
# _C101: xij_('Middlesex',_0) - xij_('Somerset',_0) + xprime_SomersetMercer >= 0
#
# _C102: xij_('Middlesex',_1) - xij_('Somerset',_1) + xprime_SomersetMiddlesex
#  >= 0
#
# _C103: xij_('Middlesex',_2) - xij_('Somerset',_2) + xprime_SomersetMiddlesex
#  >= 0
#
# _C104: xij_('Middlesex',_3) - xij_('Somerset',_3) + xprime_SomersetMiddlesex
#  >= 0
#
# _C105: xij_('Middlesex',_4) - xij_('Somerset',_4) + xprime_SomersetMiddlesex
#  >= 0
#
# _C106: xij_('Middlesex',_5) - xij_('Somerset',_5) + xprime_SomersetMiddlesex
#  >= 0
#
# _C107: xij_('Middlesex',_6) - xij_('Somerset',_6) + xprime_SomersetMiddlesex
#  >= 0
#
# _C108: xij_('Middlesex',_7) - xij_('Somerset',_7) + xprime_SomersetMiddlesex
#  >= 0
#
# _C109: xij_('Morris',_0) - xij_('Somerset',_0) + xprime_SomersetMiddlesex >= 0
#
# _C110: xij_('Morris',_1) - xij_('Somerset',_1) + xprime_SomersetMorris >= 0
#
# _C111: xij_('Morris',_2) - xij_('Somerset',_2) + xprime_SomersetMorris >= 0
#
# _C112: xij_('Morris',_3) - xij_('Somerset',_3) + xprime_SomersetMorris >= 0
#
# _C113: xij_('Morris',_4) - xij_('Somerset',_4) + xprime_SomersetMorris >= 0
#
# _C114: xij_('Morris',_5) - xij_('Somerset',_5) + xprime_SomersetMorris >= 0
#
# _C115: xij_('Morris',_6) - xij_('Somerset',_6) + xprime_SomersetMorris >= 0
#
# _C116: xij_('Morris',_7) - xij_('Somerset',_7) + xprime_SomersetMorris >= 0
#
# _C117: - xij_('Somerset',_0) + xij_('Union',_0) + xprime_SomersetMorris >= 0
#
# _C118: - xij_('Somerset',_1) + xij_('Union',_1) + xprime_SomersetUnion >= 0
#
# _C119: - xij_('Somerset',_2) + xij_('Union',_2) + xprime_SomersetUnion >= 0
#
# _C120: - xij_('Somerset',_3) + xij_('Union',_3) + xprime_SomersetUnion >= 0
#
# _C121: - xij_('Somerset',_4) + xij_('Union',_4) + xprime_SomersetUnion >= 0
#
# _C122: - xij_('Somerset',_5) + xij_('Union',_5) + xprime_SomersetUnion >= 0
#
# _C123: - xij_('Somerset',_6) + xij_('Union',_6) + xprime_SomersetUnion >= 0
#
# _C124: - xij_('Somerset',_7) + xij_('Union',_7) + xprime_SomersetUnion >= 0
#
# _C125: - xij_('Mercer',_0) + xij_('Middlesex',_0) + xprime_SomersetUnion >= 0
#
# _C126: - xij_('Mercer',_1) + xij_('Middlesex',_1) + xprime_MercerMiddlesex
#  >= 0
#
# _C127: - xij_('Mercer',_2) + xij_('Middlesex',_2) + xprime_MercerMiddlesex
#  >= 0
#
# _C128: - xij_('Mercer',_3) + xij_('Middlesex',_3) + xprime_MercerMiddlesex
#  >= 0
#
# _C129: - xij_('Mercer',_4) + xij_('Middlesex',_4) + xprime_MercerMiddlesex
#  >= 0
#
# _C130: - xij_('Mercer',_5) + xij_('Middlesex',_5) + xprime_MercerMiddlesex
#  >= 0
#
# _C131: - xij_('Mercer',_6) + xij_('Middlesex',_6) + xprime_MercerMiddlesex
#  >= 0
#
# _C132: - xij_('Mercer',_7) + xij_('Middlesex',_7) + xprime_MercerMiddlesex
#  >= 0
#
# _C133: xij_('Essex',_0) - xij_('Morris',_0) + xprime_MercerMiddlesex >= 0
#
# _C134: xij_('Essex',_1) - xij_('Morris',_1) + xprime_MorrisEssex >= 0
#
# _C135: xij_('Essex',_2) - xij_('Morris',_2) + xprime_MorrisEssex >= 0
#
# _C136: xij_('Essex',_3) - xij_('Morris',_3) + xprime_MorrisEssex >= 0
#
# _C137: xij_('Essex',_4) - xij_('Morris',_4) + xprime_MorrisEssex >= 0
#
# _C138: xij_('Essex',_5) - xij_('Morris',_5) + xprime_MorrisEssex >= 0
#
# _C139: xij_('Essex',_6) - xij_('Morris',_6) + xprime_MorrisEssex >= 0
#
# _C140: xij_('Essex',_7) - xij_('Morris',_7) + xprime_MorrisEssex >= 0
#
# _C141: - xij_('Morris',_0) + xij_('Passaic',_0) + xprime_MorrisEssex >= 0
#
# _C142: - xij_('Morris',_1) + xij_('Passaic',_1) + xprime_MorrisPassaic >= 0
#
# _C143: - xij_('Morris',_2) + xij_('Passaic',_2) + xprime_MorrisPassaic >= 0
#
# _C144: - xij_('Morris',_3) + xij_('Passaic',_3) + xprime_MorrisPassaic >= 0
#
# _C145: - xij_('Morris',_4) + xij_('Passaic',_4) + xprime_MorrisPassaic >= 0
#
# _C146: - xij_('Morris',_5) + xij_('Passaic',_5) + xprime_MorrisPassaic >= 0
#
# _C147: - xij_('Morris',_6) + xij_('Passaic',_6) + xprime_MorrisPassaic >= 0
#
# _C148: - xij_('Morris',_7) + xij_('Passaic',_7) + xprime_MorrisPassaic >= 0
#
# _C149: - xij_('Morris',_0) + xij_('Union',_0) + xprime_MorrisPassaic >= 0
#
# _C150: - xij_('Morris',_1) + xij_('Union',_1) + xprime_MorrisUnion >= 0
#
# _C151: - xij_('Morris',_2) + xij_('Union',_2) + xprime_MorrisUnion >= 0
#
# _C152: - xij_('Morris',_3) + xij_('Union',_3) + xprime_MorrisUnion >= 0
#
# _C153: - xij_('Morris',_4) + xij_('Union',_4) + xprime_MorrisUnion >= 0
#
# _C154: - xij_('Morris',_5) + xij_('Union',_5) + xprime_MorrisUnion >= 0
#
# _C155: - xij_('Morris',_6) + xij_('Union',_6) + xprime_MorrisUnion >= 0
#
# _C156: - xij_('Morris',_7) + xij_('Union',_7) + xprime_MorrisUnion >= 0
#
# _C157: xij_('Bergen',_0) - xij_('Passaic',_0) + xprime_MorrisUnion >= 0
#
# _C158: xij_('Bergen',_1) - xij_('Passaic',_1) + xprime_PassaicBergen >= 0
#
# _C159: xij_('Bergen',_2) - xij_('Passaic',_2) + xprime_PassaicBergen >= 0
#
# _C160: xij_('Bergen',_3) - xij_('Passaic',_3) + xprime_PassaicBergen >= 0
#
# _C161: xij_('Bergen',_4) - xij_('Passaic',_4) + xprime_PassaicBergen >= 0
#
# _C162: xij_('Bergen',_5) - xij_('Passaic',_5) + xprime_PassaicBergen >= 0
#
# _C163: xij_('Bergen',_6) - xij_('Passaic',_6) + xprime_PassaicBergen >= 0
#
# _C164: xij_('Bergen',_7) - xij_('Passaic',_7) + xprime_PassaicBergen >= 0
#
# _C165: xij_('Essex',_0) - xij_('Passaic',_0) + xprime_PassaicBergen >= 0
#
# _C166: xij_('Essex',_1) - xij_('Passaic',_1) + xprime_PassaicEssex >= 0
#
# _C167: xij_('Essex',_2) - xij_('Passaic',_2) + xprime_PassaicEssex >= 0
#
# _C168: xij_('Essex',_3) - xij_('Passaic',_3) + xprime_PassaicEssex >= 0
#
# _C169: xij_('Essex',_4) - xij_('Passaic',_4) + xprime_PassaicEssex >= 0
#
# _C170: xij_('Essex',_5) - xij_('Passaic',_5) + xprime_PassaicEssex >= 0
#
# _C171: xij_('Essex',_6) - xij_('Passaic',_6) + xprime_PassaicEssex >= 0
#
# _C172: xij_('Essex',_7) - xij_('Passaic',_7) + xprime_PassaicEssex >= 0
#
# _C173: xij_('Essex',_0) - xij_('Union',_0) + xprime_PassaicEssex >= 0
#
# _C174: xij_('Essex',_1) - xij_('Union',_1) + xprime_UnionEssex >= 0
#
# _C175: xij_('Essex',_2) - xij_('Union',_2) + xprime_UnionEssex >= 0
#
# _C176: xij_('Essex',_3) - xij_('Union',_3) + xprime_UnionEssex >= 0
#
# _C177: xij_('Essex',_4) - xij_('Union',_4) + xprime_UnionEssex >= 0
#
# _C178: xij_('Essex',_5) - xij_('Union',_5) + xprime_UnionEssex >= 0
#
# _C179: xij_('Essex',_6) - xij_('Union',_6) + xprime_UnionEssex >= 0
#
# _C180: xij_('Essex',_7) - xij_('Union',_7) + xprime_UnionEssex >= 0
#
# _C181: xij_('Hudson',_0) - xij_('Union',_0) + xprime_UnionEssex >= 0
#
# _C182: xij_('Hudson',_1) - xij_('Union',_1) + xprime_UnionHudson >= 0
#
# _C183: xij_('Hudson',_2) - xij_('Union',_2) + xprime_UnionHudson >= 0
#
# _C184: xij_('Hudson',_3) - xij_('Union',_3) + xprime_UnionHudson >= 0
#
# _C185: xij_('Hudson',_4) - xij_('Union',_4) + xprime_UnionHudson >= 0
#
# _C186: xij_('Hudson',_5) - xij_('Union',_5) + xprime_UnionHudson >= 0
#
# _C187: xij_('Hudson',_6) - xij_('Union',_6) + xprime_UnionHudson >= 0
#
# _C188: xij_('Hudson',_7) - xij_('Union',_7) + xprime_UnionHudson >= 0
#
# _C189: xij_('Middlesex',_0) - xij_('Union',_0) + xprime_UnionHudson >= 0
#
# _C190: xij_('Middlesex',_1) - xij_('Union',_1) + xprime_UnionMiddlesex >= 0
#
# _C191: xij_('Middlesex',_2) - xij_('Union',_2) + xprime_UnionMiddlesex >= 0
#
# _C192: xij_('Middlesex',_3) - xij_('Union',_3) + xprime_UnionMiddlesex >= 0
#
# _C193: xij_('Middlesex',_4) - xij_('Union',_4) + xprime_UnionMiddlesex >= 0
#
# _C194: xij_('Middlesex',_5) - xij_('Union',_5) + xprime_UnionMiddlesex >= 0
#
# _C195: xij_('Middlesex',_6) - xij_('Union',_6) + xprime_UnionMiddlesex >= 0
#
# _C196: xij_('Middlesex',_7) - xij_('Union',_7) + xprime_UnionMiddlesex >= 0
#
# _C197: xij_('Bergen',_0) - xij_('Hudson',_0) + xprime_UnionMiddlesex >= 0
#
# _C198: xij_('Bergen',_1) - xij_('Hudson',_1) + xprime_HudsonBergen >= 0
#
# _C199: xij_('Bergen',_2) - xij_('Hudson',_2) + xprime_HudsonBergen >= 0
#
# _C200: xij_('Bergen',_3) - xij_('Hudson',_3) + xprime_HudsonBergen >= 0
#
# _C201: xij_('Bergen',_4) - xij_('Hudson',_4) + xprime_HudsonBergen >= 0
#
# _C202: xij_('Bergen',_5) - xij_('Hudson',_5) + xprime_HudsonBergen >= 0
#
# _C203: xij_('Bergen',_6) - xij_('Hudson',_6) + xprime_HudsonBergen >= 0
#
# _C204: xij_('Bergen',_7) - xij_('Hudson',_7) + xprime_HudsonBergen >= 0
#
# _C205: xij_('Essex',_0) - xij_('Hudson',_0) + xprime_HudsonBergen >= 0
#
# _C206: xij_('Essex',_1) - xij_('Hudson',_1) + xprime_HudsonEssex >= 0
#
# _C207: xij_('Essex',_2) - xij_('Hudson',_2) + xprime_HudsonEssex >= 0
#
# _C208: xij_('Essex',_3) - xij_('Hudson',_3) + xprime_HudsonEssex >= 0
#
# _C209: xij_('Essex',_4) - xij_('Hudson',_4) + xprime_HudsonEssex >= 0
#
# _C210: xij_('Essex',_5) - xij_('Hudson',_5) + xprime_HudsonEssex >= 0
#
# _C211: xij_('Essex',_6) - xij_('Hudson',_6) + xprime_HudsonEssex >= 0
#
# _C212: xij_('Essex',_7) - xij_('Hudson',_7) + xprime_HudsonEssex >= 0
#
# _C213: xij_('Bergen',_0) - xij_('Essex',_0) + xprime_HudsonEssex >= 0
#
# _C214: xij_('Bergen',_1) - xij_('Essex',_1) + xprime_EssexBergen >= 0
#
# _C215: xij_('Bergen',_2) - xij_('Essex',_2) + xprime_EssexBergen >= 0
#
# _C216: xij_('Bergen',_3) - xij_('Essex',_3) + xprime_EssexBergen >= 0
#
# _C217: xij_('Bergen',_4) - xij_('Essex',_4) + xprime_EssexBergen >= 0
#
# _C218: xij_('Bergen',_5) - xij_('Essex',_5) + xprime_EssexBergen >= 0
#
# _C219: xij_('Bergen',_6) - xij_('Essex',_6) + xprime_EssexBergen >= 0
#
# _C220: xij_('Bergen',_7) - xij_('Essex',_7) + xprime_EssexBergen >= 0
#
# _C221: - xij_('Hunterdon',_0) + xij_('Warren',_0) + xprime_EssexBergen >= 0
#
# _C222: - xij_('Hunterdon',_1) + xij_('Warren',_1) + xprime_WarrenHunterdon
#  >= 0
#
# _C223: - xij_('Hunterdon',_2) + xij_('Warren',_2) + xprime_WarrenHunterdon
#  >= 0
#
# _C224: - xij_('Hunterdon',_3) + xij_('Warren',_3) + xprime_WarrenHunterdon
#  >= 0
#
# _C225: - xij_('Hunterdon',_4) + xij_('Warren',_4) + xprime_WarrenHunterdon
#  >= 0
#
# _C226: - xij_('Hunterdon',_5) + xij_('Warren',_5) + xprime_WarrenHunterdon
#  >= 0
#
# _C227: - xij_('Hunterdon',_6) + xij_('Warren',_6) + xprime_WarrenHunterdon
#  >= 0
#
# _C228: - xij_('Hunterdon',_7) + xij_('Warren',_7) + xprime_WarrenHunterdon
#  >= 0
#
# _C229: - xij_('Morris',_0) + xij_('Warren',_0) + xprime_WarrenHunterdon >= 0
#
# _C230: - xij_('Morris',_1) + xij_('Warren',_1) + xprime_WarrenMorris >= 0
#
# _C231: - xij_('Morris',_2) + xij_('Warren',_2) + xprime_WarrenMorris >= 0
#
# _C232: - xij_('Morris',_3) + xij_('Warren',_3) + xprime_WarrenMorris >= 0
#
# _C233: - xij_('Morris',_4) + xij_('Warren',_4) + xprime_WarrenMorris >= 0
#
# _C234: - xij_('Morris',_5) + xij_('Warren',_5) + xprime_WarrenMorris >= 0
#
# _C235: - xij_('Morris',_6) + xij_('Warren',_6) + xprime_WarrenMorris >= 0
#
# _C236: - xij_('Morris',_7) + xij_('Warren',_7) + xprime_WarrenMorris >= 0
#
# _C237: - xij_('Sussex',_0) + xij_('Warren',_0) + xprime_WarrenMorris >= 0
#
# _C238: - xij_('Sussex',_1) + xij_('Warren',_1) + xprime_WarrenSussex >= 0
#
# _C239: - xij_('Sussex',_2) + xij_('Warren',_2) + xprime_WarrenSussex >= 0
#
# _C240: - xij_('Sussex',_3) + xij_('Warren',_3) + xprime_WarrenSussex >= 0
#
# _C241: - xij_('Sussex',_4) + xij_('Warren',_4) + xprime_WarrenSussex >= 0
#
# _C242: - xij_('Sussex',_5) + xij_('Warren',_5) + xprime_WarrenSussex >= 0
#
# _C243: - xij_('Sussex',_6) + xij_('Warren',_6) + xprime_WarrenSussex >= 0
#
# _C244: - xij_('Sussex',_7) + xij_('Warren',_7) + xprime_WarrenSussex >= 0
#
# _C245: xij_('Hunterdon',_0) - xij_('Mercer',_0) + xprime_WarrenSussex >= 0
#
# _C246: xij_('Hunterdon',_1) - xij_('Mercer',_1) + xprime_HunterdonMercer >= 0
#
# _C247: xij_('Hunterdon',_2) - xij_('Mercer',_2) + xprime_HunterdonMercer >= 0
#
# _C248: xij_('Hunterdon',_3) - xij_('Mercer',_3) + xprime_HunterdonMercer >= 0
#
# _C249: xij_('Hunterdon',_4) - xij_('Mercer',_4) + xprime_HunterdonMercer >= 0
#
# _C250: xij_('Hunterdon',_5) - xij_('Mercer',_5) + xprime_HunterdonMercer >= 0
#
# _C251: xij_('Hunterdon',_6) - xij_('Mercer',_6) + xprime_HunterdonMercer >= 0
#
# _C252: xij_('Hunterdon',_7) - xij_('Mercer',_7) + xprime_HunterdonMercer >= 0
#
# _C253: xij_('Hunterdon',_0) - xij_('Morris',_0) + xprime_HunterdonMercer >= 0
#
# _C254: xij_('Hunterdon',_1) - xij_('Morris',_1) + xprime_HunterdonMorris >= 0
#
# _C255: xij_('Hunterdon',_2) - xij_('Morris',_2) + xprime_HunterdonMorris >= 0
#
# _C256: xij_('Hunterdon',_3) - xij_('Morris',_3) + xprime_HunterdonMorris >= 0
#
# _C257: xij_('Hunterdon',_4) - xij_('Morris',_4) + xprime_HunterdonMorris >= 0
#
# _C258: xij_('Hunterdon',_5) - xij_('Morris',_5) + xprime_HunterdonMorris >= 0
#
# _C259: xij_('Hunterdon',_6) - xij_('Morris',_6) + xprime_HunterdonMorris >= 0
#
# _C260: xij_('Hunterdon',_7) - xij_('Morris',_7) + xprime_HunterdonMorris >= 0
#
# _C261: xij_('Hunterdon',_0) - xij_('Somerset',_0) + xprime_HunterdonMorris
#  >= 0
#
# _C262: xij_('Hunterdon',_1) - xij_('Somerset',_1) + xprime_HunterdonSomerset
#  >= 0
#
# _C263: xij_('Hunterdon',_2) - xij_('Somerset',_2) + xprime_HunterdonSomerset
#  >= 0
#
# _C264: xij_('Hunterdon',_3) - xij_('Somerset',_3) + xprime_HunterdonSomerset
#  >= 0
#
# _C265: xij_('Hunterdon',_4) - xij_('Somerset',_4) + xprime_HunterdonSomerset
#  >= 0
#
# _C266: xij_('Hunterdon',_5) - xij_('Somerset',_5) + xprime_HunterdonSomerset
#  >= 0
#
# _C267: xij_('Hunterdon',_6) - xij_('Somerset',_6) + xprime_HunterdonSomerset
#  >= 0
#
# _C268: xij_('Hunterdon',_7) - xij_('Somerset',_7) + xprime_HunterdonSomerset
#  >= 0
#
# _C269: - xij_('Morris',_0) + xij_('Sussex',_0) + xprime_HunterdonSomerset >= 0
#
# _C270: - xij_('Morris',_1) + xij_('Sussex',_1) + xprime_SussexMorris >= 0
#
# _C271: - xij_('Morris',_2) + xij_('Sussex',_2) + xprime_SussexMorris >= 0
#
# _C272: - xij_('Morris',_3) + xij_('Sussex',_3) + xprime_SussexMorris >= 0
#
# _C273: - xij_('Morris',_4) + xij_('Sussex',_4) + xprime_SussexMorris >= 0
#
# _C274: - xij_('Morris',_5) + xij_('Sussex',_5) + xprime_SussexMorris >= 0
#
# _C275: - xij_('Morris',_6) + xij_('Sussex',_6) + xprime_SussexMorris >= 0
#
# _C276: - xij_('Morris',_7) + xij_('Sussex',_7) + xprime_SussexMorris >= 0
#
# _C277: - xij_('Passaic',_0) + xij_('Sussex',_0) + xprime_SussexMorris >= 0
#
# _C278: - xij_('Passaic',_1) + xij_('Sussex',_1) + xprime_SussexPassaic >= 0
#
# _C279: - xij_('Passaic',_2) + xij_('Sussex',_2) + xprime_SussexPassaic >= 0
#
# _C280: - xij_('Passaic',_3) + xij_('Sussex',_3) + xprime_SussexPassaic >= 0
#
# _C281: - xij_('Passaic',_4) + xij_('Sussex',_4) + xprime_SussexPassaic >= 0
#
# _C282: - xij_('Passaic',_5) + xij_('Sussex',_5) + xprime_SussexPassaic >= 0
#
# _C283: - xij_('Passaic',_6) + xij_('Sussex',_6) + xprime_SussexPassaic >= 0
#
# _C284: - xij_('Passaic',_7) + xij_('Sussex',_7) + xprime_SussexPassaic >= 0
#
# _C285: - xij_('Mercer',_0) + xij_('Somerset',_0) + xprime_SussexPassaic >= 0
#
# _C286: - xij_('Mercer',_1) + xij_('Somerset',_1) + xprime_SomersetMercer >= 0
#
# _C287: - xij_('Mercer',_2) + xij_('Somerset',_2) + xprime_SomersetMercer >= 0
#
# _C288: - xij_('Mercer',_3) + xij_('Somerset',_3) + xprime_SomersetMercer >= 0
#
# _C289: - xij_('Mercer',_4) + xij_('Somerset',_4) + xprime_SomersetMercer >= 0
#
# _C290: - xij_('Mercer',_5) + xij_('Somerset',_5) + xprime_SomersetMercer >= 0
#
# _C291: - xij_('Mercer',_6) + xij_('Somerset',_6) + xprime_SomersetMercer >= 0
#
# _C292: - xij_('Mercer',_7) + xij_('Somerset',_7) + xprime_SomersetMercer >= 0
#
# _C293: - xij_('Middlesex',_0) + xij_('Somerset',_0) + xprime_SomersetMercer
#  >= 0
#
# _C294: - xij_('Middlesex',_1) + xij_('Somerset',_1) + xprime_SomersetMiddlesex
#  >= 0
#
# _C295: - xij_('Middlesex',_2) + xij_('Somerset',_2) + xprime_SomersetMiddlesex
#  >= 0
#
# _C296: - xij_('Middlesex',_3) + xij_('Somerset',_3) + xprime_SomersetMiddlesex
#  >= 0
#
# _C297: - xij_('Middlesex',_4) + xij_('Somerset',_4) + xprime_SomersetMiddlesex
#  >= 0
#
# _C298: - xij_('Middlesex',_5) + xij_('Somerset',_5) + xprime_SomersetMiddlesex
#  >= 0
#
# _C299: - xij_('Middlesex',_6) + xij_('Somerset',_6) + xprime_SomersetMiddlesex
#  >= 0
#
# _C300: - xij_('Middlesex',_7) + xij_('Somerset',_7) + xprime_SomersetMiddlesex
#  >= 0
#
# _C301: - xij_('Morris',_0) + xij_('Somerset',_0) + xprime_SomersetMiddlesex
#  >= 0
#
# _C302: - xij_('Morris',_1) + xij_('Somerset',_1) + xprime_SomersetMorris >= 0
#
# _C303: - xij_('Morris',_2) + xij_('Somerset',_2) + xprime_SomersetMorris >= 0
#
# _C304: - xij_('Morris',_3) + xij_('Somerset',_3) + xprime_SomersetMorris >= 0
#
# _C305: - xij_('Morris',_4) + xij_('Somerset',_4) + xprime_SomersetMorris >= 0
#
# _C306: - xij_('Morris',_5) + xij_('Somerset',_5) + xprime_SomersetMorris >= 0
#
# _C307: - xij_('Morris',_6) + xij_('Somerset',_6) + xprime_SomersetMorris >= 0
#
# _C308: - xij_('Morris',_7) + xij_('Somerset',_7) + xprime_SomersetMorris >= 0
#
# _C309: xij_('Somerset',_0) - xij_('Union',_0) + xprime_SomersetMorris >= 0
#
# _C310: xij_('Somerset',_1) - xij_('Union',_1) + xprime_SomersetUnion >= 0
#
# _C311: xij_('Somerset',_2) - xij_('Union',_2) + xprime_SomersetUnion >= 0
#
# _C312: xij_('Somerset',_3) - xij_('Union',_3) + xprime_SomersetUnion >= 0
#
# _C313: xij_('Somerset',_4) - xij_('Union',_4) + xprime_SomersetUnion >= 0
#
# _C314: xij_('Somerset',_5) - xij_('Union',_5) + xprime_SomersetUnion >= 0
#
# _C315: xij_('Somerset',_6) - xij_('Union',_6) + xprime_SomersetUnion >= 0
#
# _C316: xij_('Somerset',_7) - xij_('Union',_7) + xprime_SomersetUnion >= 0
#
# _C317: xij_('Mercer',_0) - xij_('Middlesex',_0) + xprime_SomersetUnion >= 0
#
# _C318: xij_('Mercer',_1) - xij_('Middlesex',_1) + xprime_MercerMiddlesex >= 0
#
# _C319: xij_('Mercer',_2) - xij_('Middlesex',_2) + xprime_MercerMiddlesex >= 0
#
# _C320: xij_('Mercer',_3) - xij_('Middlesex',_3) + xprime_MercerMiddlesex >= 0
#
# _C321: xij_('Mercer',_4) - xij_('Middlesex',_4) + xprime_MercerMiddlesex >= 0
#
# _C322: xij_('Mercer',_5) - xij_('Middlesex',_5) + xprime_MercerMiddlesex >= 0
#
# _C323: xij_('Mercer',_6) - xij_('Middlesex',_6) + xprime_MercerMiddlesex >= 0
#
# _C324: xij_('Mercer',_7) - xij_('Middlesex',_7) + xprime_MercerMiddlesex >= 0
#
# _C325: - xij_('Essex',_0) + xij_('Morris',_0) + xprime_MercerMiddlesex >= 0
#
# _C326: - xij_('Essex',_1) + xij_('Morris',_1) + xprime_MorrisEssex >= 0
#
# _C327: - xij_('Essex',_2) + xij_('Morris',_2) + xprime_MorrisEssex >= 0
#
# _C328: - xij_('Essex',_3) + xij_('Morris',_3) + xprime_MorrisEssex >= 0
#
# _C329: - xij_('Essex',_4) + xij_('Morris',_4) + xprime_MorrisEssex >= 0
#
# _C330: - xij_('Essex',_5) + xij_('Morris',_5) + xprime_MorrisEssex >= 0
#
# _C331: - xij_('Essex',_6) + xij_('Morris',_6) + xprime_MorrisEssex >= 0
#
# _C332: - xij_('Essex',_7) + xij_('Morris',_7) + xprime_MorrisEssex >= 0
#
# _C333: xij_('Morris',_0) - xij_('Passaic',_0) + xprime_MorrisEssex >= 0
#
# _C334: xij_('Morris',_1) - xij_('Passaic',_1) + xprime_MorrisPassaic >= 0
#
# _C335: xij_('Morris',_2) - xij_('Passaic',_2) + xprime_MorrisPassaic >= 0
#
# _C336: xij_('Morris',_3) - xij_('Passaic',_3) + xprime_MorrisPassaic >= 0
#
# _C337: xij_('Morris',_4) - xij_('Passaic',_4) + xprime_MorrisPassaic >= 0
#
# _C338: xij_('Morris',_5) - xij_('Passaic',_5) + xprime_MorrisPassaic >= 0
#
# _C339: xij_('Morris',_6) - xij_('Passaic',_6) + xprime_MorrisPassaic >= 0
#
# _C340: xij_('Morris',_7) - xij_('Passaic',_7) + xprime_MorrisPassaic >= 0
#
# _C341: xij_('Morris',_0) - xij_('Union',_0) + xprime_MorrisPassaic >= 0
#
# _C342: xij_('Morris',_1) - xij_('Union',_1) + xprime_MorrisUnion >= 0
#
# _C343: xij_('Morris',_2) - xij_('Union',_2) + xprime_MorrisUnion >= 0
#
# _C344: xij_('Morris',_3) - xij_('Union',_3) + xprime_MorrisUnion >= 0
#
# _C345: xij_('Morris',_4) - xij_('Union',_4) + xprime_MorrisUnion >= 0
#
# _C346: xij_('Morris',_5) - xij_('Union',_5) + xprime_MorrisUnion >= 0
#
# _C347: xij_('Morris',_6) - xij_('Union',_6) + xprime_MorrisUnion >= 0
#
# _C348: xij_('Morris',_7) - xij_('Union',_7) + xprime_MorrisUnion >= 0
#
# _C349: - xij_('Bergen',_0) + xij_('Passaic',_0) + xprime_MorrisUnion >= 0
#
# _C350: - xij_('Bergen',_1) + xij_('Passaic',_1) + xprime_PassaicBergen >= 0
#
# _C351: - xij_('Bergen',_2) + xij_('Passaic',_2) + xprime_PassaicBergen >= 0
#
# _C352: - xij_('Bergen',_3) + xij_('Passaic',_3) + xprime_PassaicBergen >= 0
#
# _C353: - xij_('Bergen',_4) + xij_('Passaic',_4) + xprime_PassaicBergen >= 0
#
# _C354: - xij_('Bergen',_5) + xij_('Passaic',_5) + xprime_PassaicBergen >= 0
#
# _C355: - xij_('Bergen',_6) + xij_('Passaic',_6) + xprime_PassaicBergen >= 0
#
# _C356: - xij_('Bergen',_7) + xij_('Passaic',_7) + xprime_PassaicBergen >= 0
#
# _C357: - xij_('Essex',_0) + xij_('Passaic',_0) + xprime_PassaicBergen >= 0
#
# _C358: - xij_('Essex',_1) + xij_('Passaic',_1) + xprime_PassaicEssex >= 0
#
# _C359: - xij_('Essex',_2) + xij_('Passaic',_2) + xprime_PassaicEssex >= 0
#
# _C360: - xij_('Essex',_3) + xij_('Passaic',_3) + xprime_PassaicEssex >= 0
#
# _C361: - xij_('Essex',_4) + xij_('Passaic',_4) + xprime_PassaicEssex >= 0
#
# _C362: - xij_('Essex',_5) + xij_('Passaic',_5) + xprime_PassaicEssex >= 0
#
# _C363: - xij_('Essex',_6) + xij_('Passaic',_6) + xprime_PassaicEssex >= 0
#
# _C364: - xij_('Essex',_7) + xij_('Passaic',_7) + xprime_PassaicEssex >= 0
#
# _C365: - xij_('Essex',_0) + xij_('Union',_0) + xprime_PassaicEssex >= 0
#
# _C366: - xij_('Essex',_1) + xij_('Union',_1) + xprime_UnionEssex >= 0
#
# _C367: - xij_('Essex',_2) + xij_('Union',_2) + xprime_UnionEssex >= 0
#
# _C368: - xij_('Essex',_3) + xij_('Union',_3) + xprime_UnionEssex >= 0
#
# _C369: - xij_('Essex',_4) + xij_('Union',_4) + xprime_UnionEssex >= 0
#
# _C370: - xij_('Essex',_5) + xij_('Union',_5) + xprime_UnionEssex >= 0
#
# _C371: - xij_('Essex',_6) + xij_('Union',_6) + xprime_UnionEssex >= 0
#
# _C372: - xij_('Essex',_7) + xij_('Union',_7) + xprime_UnionEssex >= 0
#
# _C373: - xij_('Hudson',_0) + xij_('Union',_0) + xprime_UnionEssex >= 0
#
# _C374: - xij_('Hudson',_1) + xij_('Union',_1) + xprime_UnionHudson >= 0
#
# _C375: - xij_('Hudson',_2) + xij_('Union',_2) + xprime_UnionHudson >= 0
#
# _C376: - xij_('Hudson',_3) + xij_('Union',_3) + xprime_UnionHudson >= 0
#
# _C377: - xij_('Hudson',_4) + xij_('Union',_4) + xprime_UnionHudson >= 0
#
# _C378: - xij_('Hudson',_5) + xij_('Union',_5) + xprime_UnionHudson >= 0
#
# _C379: - xij_('Hudson',_6) + xij_('Union',_6) + xprime_UnionHudson >= 0
#
# _C380: - xij_('Hudson',_7) + xij_('Union',_7) + xprime_UnionHudson >= 0
#
# _C381: - xij_('Middlesex',_0) + xij_('Union',_0) + xprime_UnionHudson >= 0
#
# _C382: - xij_('Middlesex',_1) + xij_('Union',_1) + xprime_UnionMiddlesex >= 0
#
# _C383: - xij_('Middlesex',_2) + xij_('Union',_2) + xprime_UnionMiddlesex >= 0
#
# _C384: - xij_('Middlesex',_3) + xij_('Union',_3) + xprime_UnionMiddlesex >= 0
#
# _C385: - xij_('Middlesex',_4) + xij_('Union',_4) + xprime_UnionMiddlesex >= 0
#
# _C386: - xij_('Middlesex',_5) + xij_('Union',_5) + xprime_UnionMiddlesex >= 0
#
# _C387: - xij_('Middlesex',_6) + xij_('Union',_6) + xprime_UnionMiddlesex >= 0
#
# _C388: - xij_('Middlesex',_7) + xij_('Union',_7) + xprime_UnionMiddlesex >= 0
#
# _C389: - xij_('Bergen',_0) + xij_('Hudson',_0) + xprime_UnionMiddlesex >= 0
#
# _C390: - xij_('Bergen',_1) + xij_('Hudson',_1) + xprime_HudsonBergen >= 0
#
# _C391: - xij_('Bergen',_2) + xij_('Hudson',_2) + xprime_HudsonBergen >= 0
#
# _C392: - xij_('Bergen',_3) + xij_('Hudson',_3) + xprime_HudsonBergen >= 0
#
# _C393: - xij_('Bergen',_4) + xij_('Hudson',_4) + xprime_HudsonBergen >= 0
#
# _C394: - xij_('Bergen',_5) + xij_('Hudson',_5) + xprime_HudsonBergen >= 0
#
# _C395: - xij_('Bergen',_6) + xij_('Hudson',_6) + xprime_HudsonBergen >= 0
#
# _C396: - xij_('Bergen',_7) + xij_('Hudson',_7) + xprime_HudsonBergen >= 0
#
# _C397: - xij_('Essex',_0) + xij_('Hudson',_0) + xprime_HudsonBergen >= 0
#
# _C398: - xij_('Essex',_1) + xij_('Hudson',_1) + xprime_HudsonEssex >= 0
#
# _C399: - xij_('Essex',_2) + xij_('Hudson',_2) + xprime_HudsonEssex >= 0
#
# _C400: - xij_('Essex',_3) + xij_('Hudson',_3) + xprime_HudsonEssex >= 0
#
# _C401: - xij_('Essex',_4) + xij_('Hudson',_4) + xprime_HudsonEssex >= 0
#
# _C402: - xij_('Essex',_5) + xij_('Hudson',_5) + xprime_HudsonEssex >= 0
#
# _C403: - xij_('Essex',_6) + xij_('Hudson',_6) + xprime_HudsonEssex >= 0
#
# _C404: - xij_('Essex',_7) + xij_('Hudson',_7) + xprime_HudsonEssex >= 0
#
# _C405: - xij_('Bergen',_0) + xij_('Essex',_0) + xprime_HudsonEssex >= 0
#
# _C406: - xij_('Bergen',_1) + xij_('Essex',_1) + xprime_EssexBergen >= 0
#
# _C407: - xij_('Bergen',_2) + xij_('Essex',_2) + xprime_EssexBergen >= 0
#
# _C408: - xij_('Bergen',_3) + xij_('Essex',_3) + xprime_EssexBergen >= 0
#
# _C409: - xij_('Bergen',_4) + xij_('Essex',_4) + xprime_EssexBergen >= 0
#
# _C410: - xij_('Bergen',_5) + xij_('Essex',_5) + xprime_EssexBergen >= 0
#
# _C411: - xij_('Bergen',_6) + xij_('Essex',_6) + xprime_EssexBergen >= 0
#
# _C412: - xij_('Bergen',_7) + xij_('Essex',_7) + xprime_EssexBergen >= 0
#
# _C413: xij_('Hunterdon',_0) - xij_('Mercer',_0) - xij_('Morris',_0)
#  - xij_('Somerset',_0) - xij_('Warren',_0) <= 0
#
# _C414: - xij_('Hunterdon',_0) + xij_('Mercer',_0) - xij_('Middlesex',_0)
#  - xij_('Somerset',_0) <= 0
#
# _C415: - xij_('Essex',_0) - xij_('Hunterdon',_0) + xij_('Morris',_0)
#  - xij_('Passaic',_0) - xij_('Somerset',_0) - xij_('Sussex',_0)
#  - xij_('Union',_0) - xij_('Warren',_0) <= 0
#
# _C416: - xij_('Bergen',_0) - xij_('Essex',_0) - xij_('Morris',_0)
#  + xij_('Passaic',_0) - xij_('Sussex',_0) <= 0
#
# _C417: - xij_('Hunterdon',_0) - xij_('Mercer',_0) - xij_('Middlesex',_0)
#  - xij_('Morris',_0) + xij_('Somerset',_0) - xij_('Union',_0) <= 0
#
# _C418: - xij_('Morris',_0) - xij_('Passaic',_0) + xij_('Sussex',_0)
#  - xij_('Warren',_0) <= 0
#
# _C419: - xij_('Essex',_0) - xij_('Hudson',_0) - xij_('Middlesex',_0)
#  - xij_('Morris',_0) - xij_('Somerset',_0) + xij_('Union',_0) <= 0
#
# _C420: xij_('Hunterdon',_1) - xij_('Mercer',_1) - xij_('Morris',_1)
#  - xij_('Somerset',_1) - xij_('Warren',_1) <= 0
#
# _C421: - xij_('Hunterdon',_1) + xij_('Mercer',_1) - xij_('Middlesex',_1)
#  - xij_('Somerset',_1) <= 0
#
# _C422: - xij_('Essex',_1) - xij_('Hunterdon',_1) + xij_('Morris',_1)
#  - xij_('Passaic',_1) - xij_('Somerset',_1) - xij_('Sussex',_1)
#  - xij_('Union',_1) - xij_('Warren',_1) <= 0
#
# _C423: - xij_('Bergen',_1) - xij_('Essex',_1) - xij_('Morris',_1)
#  + xij_('Passaic',_1) - xij_('Sussex',_1) <= 0
#
# _C424: - xij_('Hunterdon',_1) - xij_('Mercer',_1) - xij_('Middlesex',_1)
#  - xij_('Morris',_1) + xij_('Somerset',_1) - xij_('Union',_1) <= 0
#
# _C425: - xij_('Morris',_1) - xij_('Passaic',_1) + xij_('Sussex',_1)
#  - xij_('Warren',_1) <= 0
#
# _C426: - xij_('Essex',_1) - xij_('Hudson',_1) - xij_('Middlesex',_1)
#  - xij_('Morris',_1) - xij_('Somerset',_1) + xij_('Union',_1) <= 0
#
# _C427: xij_('Hunterdon',_2) - xij_('Mercer',_2) - xij_('Morris',_2)
#  - xij_('Somerset',_2) - xij_('Warren',_2) <= 0
#
# _C428: - xij_('Hunterdon',_2) + xij_('Mercer',_2) - xij_('Middlesex',_2)
#  - xij_('Somerset',_2) <= 0
#
# _C429: - xij_('Essex',_2) - xij_('Hunterdon',_2) + xij_('Morris',_2)
#  - xij_('Passaic',_2) - xij_('Somerset',_2) - xij_('Sussex',_2)
#  - xij_('Union',_2) - xij_('Warren',_2) <= 0
#
# _C430: - xij_('Bergen',_2) - xij_('Essex',_2) - xij_('Morris',_2)
#  + xij_('Passaic',_2) - xij_('Sussex',_2) <= 0
#
# _C431: - xij_('Hunterdon',_2) - xij_('Mercer',_2) - xij_('Middlesex',_2)
#  - xij_('Morris',_2) + xij_('Somerset',_2) - xij_('Union',_2) <= 0
#
# _C432: - xij_('Morris',_2) - xij_('Passaic',_2) + xij_('Sussex',_2)
#  - xij_('Warren',_2) <= 0
#
# _C433: - xij_('Essex',_2) - xij_('Hudson',_2) - xij_('Middlesex',_2)
#  - xij_('Morris',_2) - xij_('Somerset',_2) + xij_('Union',_2) <= 0
#
# _C434: xij_('Hunterdon',_3) - xij_('Mercer',_3) - xij_('Morris',_3)
#  - xij_('Somerset',_3) - xij_('Warren',_3) <= 0
#
# _C435: - xij_('Hunterdon',_3) + xij_('Mercer',_3) - xij_('Middlesex',_3)
#  - xij_('Somerset',_3) <= 0
#
# _C436: - xij_('Essex',_3) - xij_('Hunterdon',_3) + xij_('Morris',_3)
#  - xij_('Passaic',_3) - xij_('Somerset',_3) - xij_('Sussex',_3)
#  - xij_('Union',_3) - xij_('Warren',_3) <= 0
#
# _C437: - xij_('Bergen',_3) - xij_('Essex',_3) - xij_('Morris',_3)
#  + xij_('Passaic',_3) - xij_('Sussex',_3) <= 0
#
# _C438: - xij_('Hunterdon',_3) - xij_('Mercer',_3) - xij_('Middlesex',_3)
#  - xij_('Morris',_3) + xij_('Somerset',_3) - xij_('Union',_3) <= 0
#
# _C439: - xij_('Morris',_3) - xij_('Passaic',_3) + xij_('Sussex',_3)
#  - xij_('Warren',_3) <= 0
#
# _C440: - xij_('Essex',_3) - xij_('Hudson',_3) - xij_('Middlesex',_3)
#  - xij_('Morris',_3) - xij_('Somerset',_3) + xij_('Union',_3) <= 0
#
# _C441: xij_('Hunterdon',_4) - xij_('Mercer',_4) - xij_('Morris',_4)
#  - xij_('Somerset',_4) - xij_('Warren',_4) <= 0
#
# _C442: - xij_('Hunterdon',_4) + xij_('Mercer',_4) - xij_('Middlesex',_4)
#  - xij_('Somerset',_4) <= 0
#
# _C443: - xij_('Essex',_4) - xij_('Hunterdon',_4) + xij_('Morris',_4)
#  - xij_('Passaic',_4) - xij_('Somerset',_4) - xij_('Sussex',_4)
#  - xij_('Union',_4) - xij_('Warren',_4) <= 0
#
# _C444: - xij_('Bergen',_4) - xij_('Essex',_4) - xij_('Morris',_4)
#  + xij_('Passaic',_4) - xij_('Sussex',_4) <= 0
#
# _C445: - xij_('Hunterdon',_4) - xij_('Mercer',_4) - xij_('Middlesex',_4)
#  - xij_('Morris',_4) + xij_('Somerset',_4) - xij_('Union',_4) <= 0
#
# _C446: - xij_('Morris',_4) - xij_('Passaic',_4) + xij_('Sussex',_4)
#  - xij_('Warren',_4) <= 0
#
# _C447: - xij_('Essex',_4) - xij_('Hudson',_4) - xij_('Middlesex',_4)
#  - xij_('Morris',_4) - xij_('Somerset',_4) + xij_('Union',_4) <= 0
#
# _C448: xij_('Hunterdon',_5) - xij_('Mercer',_5) - xij_('Morris',_5)
#  - xij_('Somerset',_5) - xij_('Warren',_5) <= 0
#
# _C449: - xij_('Hunterdon',_5) + xij_('Mercer',_5) - xij_('Middlesex',_5)
#  - xij_('Somerset',_5) <= 0
#
# _C450: - xij_('Essex',_5) - xij_('Hunterdon',_5) + xij_('Morris',_5)
#  - xij_('Passaic',_5) - xij_('Somerset',_5) - xij_('Sussex',_5)
#  - xij_('Union',_5) - xij_('Warren',_5) <= 0
#
# _C451: - xij_('Bergen',_5) - xij_('Essex',_5) - xij_('Morris',_5)
#  + xij_('Passaic',_5) - xij_('Sussex',_5) <= 0
#
# _C452: - xij_('Hunterdon',_5) - xij_('Mercer',_5) - xij_('Middlesex',_5)
#  - xij_('Morris',_5) + xij_('Somerset',_5) - xij_('Union',_5) <= 0
#
# _C453: - xij_('Morris',_5) - xij_('Passaic',_5) + xij_('Sussex',_5)
#  - xij_('Warren',_5) <= 0
#
# _C454: - xij_('Essex',_5) - xij_('Hudson',_5) - xij_('Middlesex',_5)
#  - xij_('Morris',_5) - xij_('Somerset',_5) + xij_('Union',_5) <= 0
#
# _C455: xij_('Hunterdon',_6) - xij_('Mercer',_6) - xij_('Morris',_6)
#  - xij_('Somerset',_6) - xij_('Warren',_6) <= 0
#
# _C456: - xij_('Hunterdon',_6) + xij_('Mercer',_6) - xij_('Middlesex',_6)
#  - xij_('Somerset',_6) <= 0
#
# _C457: - xij_('Essex',_6) - xij_('Hunterdon',_6) + xij_('Morris',_6)
#  - xij_('Passaic',_6) - xij_('Somerset',_6) - xij_('Sussex',_6)
#  - xij_('Union',_6) - xij_('Warren',_6) <= 0
#
# _C458: - xij_('Bergen',_6) - xij_('Essex',_6) - xij_('Morris',_6)
#  + xij_('Passaic',_6) - xij_('Sussex',_6) <= 0
#
# _C459: - xij_('Hunterdon',_6) - xij_('Mercer',_6) - xij_('Middlesex',_6)
#  - xij_('Morris',_6) + xij_('Somerset',_6) - xij_('Union',_6) <= 0
#
# _C460: - xij_('Morris',_6) - xij_('Passaic',_6) + xij_('Sussex',_6)
#  - xij_('Warren',_6) <= 0
#
# _C461: - xij_('Essex',_6) - xij_('Hudson',_6) - xij_('Middlesex',_6)
#  - xij_('Morris',_6) - xij_('Somerset',_6) + xij_('Union',_6) <= 0
#
# _C462: xij_('Hunterdon',_7) - xij_('Mercer',_7) - xij_('Morris',_7)
#  - xij_('Somerset',_7) - xij_('Warren',_7) <= 0
#
# _C463: - xij_('Hunterdon',_7) + xij_('Mercer',_7) - xij_('Middlesex',_7)
#  - xij_('Somerset',_7) <= 0
#
# _C464: - xij_('Essex',_7) - xij_('Hunterdon',_7) + xij_('Morris',_7)
#  - xij_('Passaic',_7) - xij_('Somerset',_7) - xij_('Sussex',_7)
#  - xij_('Union',_7) - xij_('Warren',_7) <= 0
#
# _C465: - xij_('Bergen',_7) - xij_('Essex',_7) - xij_('Morris',_7)
#  + xij_('Passaic',_7) - xij_('Sussex',_7) <= 0
#
# _C466: - xij_('Hunterdon',_7) - xij_('Mercer',_7) - xij_('Middlesex',_7)
#  - xij_('Morris',_7) + xij_('Somerset',_7) - xij_('Union',_7) <= 0
#
# _C467: - xij_('Morris',_7) - xij_('Passaic',_7) + xij_('Sussex',_7)
#  - xij_('Warren',_7) <= 0
#
# _C468: - xij_('Essex',_7) - xij_('Hudson',_7) - xij_('Middlesex',_7)
#  - xij_('Morris',_7) - xij_('Somerset',_7) + xij_('Union',_7) <= 0
#
# VARIABLES
# 0 <= xij_('Bergen',_0) <= 1 Integer
# 0 <= xij_('Bergen',_1) <= 1 Integer
# 0 <= xij_('Bergen',_2) <= 1 Integer
# 0 <= xij_('Bergen',_3) <= 1 Integer
# 0 <= xij_('Bergen',_4) <= 1 Integer
# 0 <= xij_('Bergen',_5) <= 1 Integer
# 0 <= xij_('Bergen',_6) <= 1 Integer
# 0 <= xij_('Bergen',_7) <= 1 Integer
# 0 <= xij_('Essex',_0) <= 1 Integer
# 0 <= xij_('Essex',_1) <= 1 Integer
# 0 <= xij_('Essex',_2) <= 1 Integer
# 0 <= xij_('Essex',_3) <= 1 Integer
# 0 <= xij_('Essex',_4) <= 1 Integer
# 0 <= xij_('Essex',_5) <= 1 Integer
# 0 <= xij_('Essex',_6) <= 1 Integer
# 0 <= xij_('Essex',_7) <= 1 Integer
# 0 <= xij_('Hudson',_0) <= 1 Integer
# 0 <= xij_('Hudson',_1) <= 1 Integer
# 0 <= xij_('Hudson',_2) <= 1 Integer
# 0 <= xij_('Hudson',_3) <= 1 Integer
# 0 <= xij_('Hudson',_4) <= 1 Integer
# 0 <= xij_('Hudson',_5) <= 1 Integer
# 0 <= xij_('Hudson',_6) <= 1 Integer
# 0 <= xij_('Hudson',_7) <= 1 Integer
# 0 <= xij_('Hunterdon',_0) <= 1 Integer
# 0 <= xij_('Hunterdon',_1) <= 1 Integer
# 0 <= xij_('Hunterdon',_2) <= 1 Integer
# 0 <= xij_('Hunterdon',_3) <= 1 Integer
# 0 <= xij_('Hunterdon',_4) <= 1 Integer
# 0 <= xij_('Hunterdon',_5) <= 1 Integer
# 0 <= xij_('Hunterdon',_6) <= 1 Integer
# 0 <= xij_('Hunterdon',_7) <= 1 Integer
# 0 <= xij_('Mercer',_0) <= 1 Integer
# 0 <= xij_('Mercer',_1) <= 1 Integer
# 0 <= xij_('Mercer',_2) <= 1 Integer
# 0 <= xij_('Mercer',_3) <= 1 Integer
# 0 <= xij_('Mercer',_4) <= 1 Integer
# 0 <= xij_('Mercer',_5) <= 1 Integer
# 0 <= xij_('Mercer',_6) <= 1 Integer
# 0 <= xij_('Mercer',_7) <= 1 Integer
# 0 <= xij_('Middlesex',_0) <= 1 Integer
# 0 <= xij_('Middlesex',_1) <= 1 Integer
# 0 <= xij_('Middlesex',_2) <= 1 Integer
# 0 <= xij_('Middlesex',_3) <= 1 Integer
# 0 <= xij_('Middlesex',_4) <= 1 Integer
# 0 <= xij_('Middlesex',_5) <= 1 Integer
# 0 <= xij_('Middlesex',_6) <= 1 Integer
# 0 <= xij_('Middlesex',_7) <= 1 Integer
# 0 <= xij_('Morris',_0) <= 1 Integer
# 0 <= xij_('Morris',_1) <= 1 Integer
# 0 <= xij_('Morris',_2) <= 1 Integer
# 0 <= xij_('Morris',_3) <= 1 Integer
# 0 <= xij_('Morris',_4) <= 1 Integer
# 0 <= xij_('Morris',_5) <= 1 Integer
# 0 <= xij_('Morris',_6) <= 1 Integer
# 0 <= xij_('Morris',_7) <= 1 Integer
# 0 <= xij_('Passaic',_0) <= 1 Integer
# 0 <= xij_('Passaic',_1) <= 1 Integer
# 0 <= xij_('Passaic',_2) <= 1 Integer
# 0 <= xij_('Passaic',_3) <= 1 Integer
# 0 <= xij_('Passaic',_4) <= 1 Integer
# 0 <= xij_('Passaic',_5) <= 1 Integer
# 0 <= xij_('Passaic',_6) <= 1 Integer
# 0 <= xij_('Passaic',_7) <= 1 Integer
# 0 <= xij_('Somerset',_0) <= 1 Integer
# 0 <= xij_('Somerset',_1) <= 1 Integer
# 0 <= xij_('Somerset',_2) <= 1 Integer
# 0 <= xij_('Somerset',_3) <= 1 Integer
# 0 <= xij_('Somerset',_4) <= 1 Integer
# 0 <= xij_('Somerset',_5) <= 1 Integer
# 0 <= xij_('Somerset',_6) <= 1 Integer
# 0 <= xij_('Somerset',_7) <= 1 Integer
# 0 <= xij_('Sussex',_0) <= 1 Integer
# 0 <= xij_('Sussex',_1) <= 1 Integer
# 0 <= xij_('Sussex',_2) <= 1 Integer
# 0 <= xij_('Sussex',_3) <= 1 Integer
# 0 <= xij_('Sussex',_4) <= 1 Integer
# 0 <= xij_('Sussex',_5) <= 1 Integer
# 0 <= xij_('Sussex',_6) <= 1 Integer
# 0 <= xij_('Sussex',_7) <= 1 Integer
# 0 <= xij_('Union',_0) <= 1 Integer
# 0 <= xij_('Union',_1) <= 1 Integer
# 0 <= xij_('Union',_2) <= 1 Integer
# 0 <= xij_('Union',_3) <= 1 Integer
# 0 <= xij_('Union',_4) <= 1 Integer
# 0 <= xij_('Union',_5) <= 1 Integer
# 0 <= xij_('Union',_6) <= 1 Integer
# 0 <= xij_('Union',_7) <= 1 Integer
# 0 <= xij_('Warren',_0) <= 1 Integer
# 0 <= xij_('Warren',_1) <= 1 Integer
# 0 <= xij_('Warren',_2) <= 1 Integer
# 0 <= xij_('Warren',_3) <= 1 Integer
# 0 <= xij_('Warren',_4) <= 1 Integer
# 0 <= xij_('Warren',_5) <= 1 Integer
# 0 <= xij_('Warren',_6) <= 1 Integer
# 0 <= xij_('Warren',_7) <= 1 Integer
# 0 <= xprime_EssexBergen <= 1 Integer
# 0 <= xprime_HudsonBergen <= 1 Integer
# 0 <= xprime_HudsonEssex <= 1 Integer
# 0 <= xprime_HunterdonMercer <= 1 Integer
# 0 <= xprime_HunterdonMorris <= 1 Integer
# 0 <= xprime_HunterdonSomerset <= 1 Integer
# 0 <= xprime_MercerMiddlesex <= 1 Integer
# 0 <= xprime_MorrisEssex <= 1 Integer
# 0 <= xprime_MorrisPassaic <= 1 Integer
# 0 <= xprime_MorrisUnion <= 1 Integer
# 0 <= xprime_PassaicBergen <= 1 Integer
# 0 <= xprime_PassaicEssex <= 1 Integer
# 0 <= xprime_SomersetMercer <= 1 Integer
# 0 <= xprime_SomersetMiddlesex <= 1 Integer
# 0 <= xprime_SomersetMorris <= 1 Integer
# 0 <= xprime_SomersetUnion <= 1 Integer
# 0 <= xprime_SussexMorris <= 1 Integer
# 0 <= xprime_SussexPassaic <= 1 Integer
# 0 <= xprime_UnionEssex <= 1 Integer
# 0 <= xprime_UnionHudson <= 1 Integer
# 0 <= xprime_UnionMiddlesex <= 1 Integer
# 0 <= xprime_WarrenHunterdon <= 1 Integer
# 0 <= xprime_WarrenMorris <= 1 Integer
# 0 <= xprime_WarrenSussex <= 1 Integer

# %% [markdown]
# ### Count the Number of Cut Edges
